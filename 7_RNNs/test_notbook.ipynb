# %%
import lib.utilities as u
import matplotlib.pyplot as plt

# %%
print(u.SEQUENCE_LENGTH)
functions = u.sample_sine_functions(5)
function = u.prepare_sequences(functions)

fig,(ax)
plt.plot(u.x,function[1][4][:])
plt.show()
# Out:
# 80
# 5

# %%
sine = u.RandomSineFunction()
prepared = u.prepare_sequences(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [80], line 2
#       1 sine = u.RandomSineFunction()
# ----> 2 prepared = u.prepare_sequences(5)
#
# File c:\Users\ASUS\Desktop\Masters\Semester 4\DL\Exercises\dl2022-ex07-rnn-dl2022-ryd\lib\utilities.py:59, in prepare_sequences(functions)
#      51 def prepare_sequences(functions: List[RandomSineFunction]) -> Tuple[torch.Tensor, torch.Tensor]:
#      52     """Convert to tensor and create noisy sequence
#      53     Args:
#      54         functions: List of RandomSineFunctions
#    (...)
#      57         Tuple of sequences and same sequences with noise of shapes (SEQUENCE_LENGTH, number of sine functions, 1)
#      58     """
# ---> 59     sequences = np.array([f(x).reshape(-1, 1) for f in functions])
#      60     # the function is in dimension 0, the sequence in dimension 1 and the value in dimension 2 with length 1
# ...
